# %% [markdown]
# Practical Questions of Data Structures and Types in Python

# %%
my_name = "Vani"
print(my_name)
# Out:
# Vani

# %%
text = "Hello World"
length = len(text)
print("The length of the string is:", length)
# Out:
# The length of the string is: 11

# %%
text = "Python Programming"
sliced_text = text[:3]
print("The first 3 characters are:", sliced_text)
# Out:
# The first 3 characters are: Pyt

# %%
text = "hello"
uppercase_text = text.upper()
print("The uppercase string is:", uppercase_text)
# Out:
# The uppercase string is: HELLO

# %%
text = "I like apple"
replaced_text = text.replace("apple", "orange")
print("The replaced string is:", replaced_text)
# Out:
# The replaced string is: I like orange

# %%
numbers = [1, 2, 3, 4, 5]
print("The list is:", numbers)
# Out:
# The list is: [1, 2, 3, 4, 5]

# %%
numbers = [1, 2, 3, 4]
numbers.append(10)
print("The updated list is:", numbers)
# Out:
# The updated list is: [1, 2, 3, 4, 10]

# %%
numbers = [1, 2, 3, 4, 5]
numbers.remove(3)
print("The updated list is:", numbers)
# Out:
# The updated list is: [1, 2, 4, 5]

# %%
letters = ['a', 'b', 'c', 'd']
second_element = letters[1]
print("The second element is:", second_element)
# Out:
# The second element is: b

# %%
numbers = [10, 20, 30, 40, 50]
numbers.reverse()
print("The reversed list is:", numbers)
# Out:
# The reversed list is: [50, 40, 30, 20, 10]

# %%
tuple = (100, 200, 300)
print(tuple)
# Out:
# (100, 200, 300)

# %%
colours = ('red', 'green', 'blue', 'yellow')
second_to_last = colours[-2]
print(second_to_last)
# Out:
# blue

# %%
numbers = (10, 20, 5, 15)
minimum = min(numbers)
print(minimum)
# Out:
# 5

# %%
animals = ('dog', 'cat', 'rabbit')
index = animals.index('cat')
print(index)
# Out:
# 1

# %%
fruits = ("apple", "banana", "mango")
is_kiwi_present = "kiwi" in fruits
print(is_kiwi_present)
# Out:
# False

# %%
set = {'a', 'b', 'c'}
print(set)
# Out:
# {'b', 'a', 'c'}

# %%
set = {1, 2, 3, 4, 5}
set.clear()
print(set)
# Out:
# set()

# %%
set = {1, 2, 3, 4}
set.remove(4)
print(set)
# Out:
# {1, 2, 3}

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}
union_set = set1.union(set2)
print(union_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
set1 = {1, 2, 3}
set2 = {2, 3, 4}
intersection_set = set1.intersection(set2)
print(intersection_set)
# Out:
# {2, 3}

# %%
person = {"name": "Vani", "age": 20, "city": "Mumbai"}
print("The Dictionary is:",person)
# Out:
# The Dictionary is: {'name': 'Vani', 'age': 20, 'city': 'Mumbai'}

# %%
person = {'name': 'John', 'age': 25}
person["country"] = "USA"
print("The updated Dictionary is:",person)
# Out:
# The updated Dictionary is: {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
person =  {'name': 'Alice', 'age': 30}
name_value = person['name']
print("The value of 'name' is:", name_value)
# Out:
# The value of 'name' is: Alice

# %%
person = {'name': 'Bob', 'age': 22, 'city': 'New York'}
person.pop('age')
print(person)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
person = {'name': 'Alice', 'city': 'Paris'}
key_exists = 'city' in person
print("Does the key 'city' exist?", key_exists)
# Out:
# Does the key 'city' exist? True

# %%
list = [10,20,30,40]
tuple = ("apple", "banana", "mango")
dict = {'name': 'Vani', 'age': 20}
print("List:", list)
print("Tuple:", tuple)
print("Dictionary:", dict)
# Out:
# List: [10, 20, 30, 40]
# Tuple: ('apple', 'banana', 'mango')
# Dictionary: {'name': 'Vani', 'age': 20}

# %%
import random
random_numbers = [random.randint(1, 100) for _ in range(5)]
random_numbers.sort()
print("Sorted list of random numbers:", random_numbers)
# Out:
# Sorted list of random numbers: [27, 54, 63, 78, 85]

# %%
my_list = ['apple', 'banana', 'cherry', 'date', 'elderberry']
print("Element at the third index is:", my_list[3])
# Out:
# Element at the third index is: date

# %%
dict1 = {'a': 1, 'b': 2}
dict2 = {'c': 3, 'd': 4}
combined_dict = dict1 | dict2
print("Combined dictionary:", combined_dict)
# Out:
# Combined dictionary: {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
list = ('apple', 'banana', 'apple', 'cherry', 'banana')
# Rename the variable 'set' to 'my_set' or another descriptive name
my_set = set(list)
print("List as a set:", my_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-c808cbb1cf52> in <cell line: 0>()
#       1 list = ('apple', 'banana', 'apple', 'cherry', 'banana')
#       2 # Rename the variable 'set' to 'my_set' or another descriptive name
# ----> 3 my_set = set(list)
#       4 print("List as a set:", my_set)
#
# TypeError: 'set' object is not callable
